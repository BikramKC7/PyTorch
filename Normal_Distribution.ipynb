# %% [markdown]
# <a href="https://colab.research.google.com/github/BikramKC7/PyTorch/blob/main/Normal_Distribution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import seaborn as sea

# %%
data_path = '/content/drive/MyDrive/weight-height.csv'

# %%
df = pd.read_csv(data_path)
df.head()
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %%
df.drop('Weight',axis=1, inplace=True)

# %%
df.head()
# Out:
#   Gender     Height
# 0   Male  73.847017
# 1   Male  68.781904
# 2   Male  74.110105
# 3   Male  71.730978
# 4   Male  69.881796

# %%
df.Height.describe()
# Out:
# count    10000.000000
# mean        66.367560
# std          3.847528
# min         54.263133
# 25%         63.505620
# 50%         66.318070
# 75%         69.174262
# max         78.998742
# Name: Height, dtype: float64

# %%
sea.histplot(df.Height, kde=True)
# Out:
# <Axes: xlabel='Height', ylabel='Count'>

# %%
mean = df.Height.mean()
mean
# Out:
# np.float64(66.36755975482124)

# %%
s_deviation = df.Height.std()
s_deviation
# Out:
# 3.8475281207732324

# %%
mean+3*s_deviation
# Out:
# np.float64(77.91014411714094)

# %%
mean-3*s_deviation
# Out:
# np.float64(54.82497539250154)

# %%
df[(df.Height <54.82) | (df.Height>77.91)]
# Out:
#       Gender     Height
# 994     Male  78.095867
# 1317    Male  78.462053
# 2014    Male  78.998742
# 3285    Male  78.528210
# 3757    Male  78.621374
# 6624  Female  54.616858
# 9285  Female  54.263133

# %%
df_noutlier = df[(df.Height >54.82) & (df.Height<77.91)]

# %%
df_noutlier.shape
# Out:
# (9993, 2)

# %%
sea.histplot(df_noutlier.Height, kde=True)
# Out:
# <Axes: xlabel='Height', ylabel='Count'>
